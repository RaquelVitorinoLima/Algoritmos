# %% [markdown]
# ## Trabalho de casa nº4

# %% [markdown]
# **Identificador**: Trabalho
#
# **Título**: Gestor de Frações
#
# **Data início**: 2021-10-26 **Data fim**: 2021-10-30
#
# **Supervisor**: José Carlos Ramalho, https://www.di.uminho.pt/~jcr/thesup-v2.php
#
# **Autor**: Raquel Vitorino Lima, A97590

# %% [markdown]
# ### Resumo:

# %% [markdown]
# Com o trabalho proposto, pretende-se fazer várias operações com frações. Com o gestor de frações elaborado, podemos realizar a soma, subtração, multiplicação e divisão entre duas frações criadas pela utilizador. Podemos ainda gerar uma lista de frações aleatória com o número de elementos que o utilizador desejar e fazer a soma dos seus elementos ou então podemos mesmo criar duas listas aletórias de frações e fazer a respetiva soma das duas. Por fim, o algoritmo permite ainda verificar qual o maior elemento da lista em questão.

# %% [markdown]
# ### Código:

# %%
from random import randint

def menu():
    print(""" Gestão para trabalhar com frações
          Selecione a opção que pretende fazer:
          (1)- Criar fração
          (2)- Simplificar fração
          (3)- Soma de frações
          (4)- Subtração de frações
          (5)- Multiplicação de frações
          (6)- Divisão de frações
          (7)- Gerar lista de n frações
          (8)- Somatório dos elementos de uma lista
          (9)- Somatório dos elementos de duas listas
          (10)- Maior fração da lista
          (0)- sair
          """)
          

def criarFrac( num, denom):
    return (num, denom)

def verFrac(f):
    print (str(f[0]) + "/" + str(f[1]))

def mdc(a,b):
    if int(a)<int(b):
        return mdc (b,a)
    elif int(a)%int(b)==0:
        return b
    else:
        return mdc(a, a%b)

def simplificarFrac(f):
    num, denom= f
    a= mdc(num,denom)
    return ((int(num))/(int(a)), (int(denom))/(int(a)))

            
def somarFrac(f1,f2):
   num1, denom1=f1
   num2, denom2=f2
   num=(int(num1))* (int(denom2)) + (int(num2))*(int(denom1))
   denom= int(denom1)*(int(denom2))
   return simplificarFrac(criarFrac(num, denom))
                            
                            
def subtrairFrac(f1,f2):
   num1, denom1=f1
   num2, denom2=f2
   num=int(num1)*int(denom2) -int(num2)*int(denom1)
   denom= int(denom1)*int(denom2)
   return simplificarFrac(criarFrac(num,denom))


def multiplicarFrac(f1, f2):
   num1, denom1=f1
   num2, denom2=f2
   num=int(num1)* int(num2)
   denom= int(denom1)*int(denom2)
   return simplificarFrac(criarFrac(num,denom))


def dividirFrac(f1,f2):
   num1, denom1=f1
   num2, denom2=f2
   num=int(num1)* int(denom2)
   denom= int(num2)*int(denom1)
   return simplificarFrac(criarFrac(num,denom))
    


def gerarLista():
    L=[]
    elem= int(input("Introduza o número de elementos que deseja para a sua lista:"))
    for i in range(elem):
         gerarNum=randint(1,100)
         gerarDenom=randint(1,100)
         L.append((gerarNum, gerarDenom))
         if ((gerarNum % gerarDenom )==0):
                gerarNum=randint(1,100)
                gerarDenom=randint(1,100)
                L.append((gerarNum, gerarDenom))
         elif gerarNum== gerarDenom: 
                gerarNum=randint(1,100)
                gerarDenom=randint(1,100)
                L.append((gerarNum, gerarDenom))
    return L
    return simplificarFrac(criarFrac())    


def somatorioLista(L):
     soma = (0, 1)
     for elem in L:
         soma = somarFrac(soma, elem)
     return (soma)
     return simplificarFrac(somatorioLista(L))
    
    
def somarListas( L1,L2):
    if (len(L1) != (len(L2))): 
        print ("Impossível fazer a soma das listas pretendidas")
    else:
        SL=[]
        for i in range (len(L1)):
            temp= somarFrac (L1[i],L2[i]) 
            SL.append(temp)
    return SL
    print(" A lista correspondente à soma das suas duas listas é: ", SL)
    
    
    
def maiorFrac(L):
    L1 = []
    for i in range(len(L)-1):
        num, denom = L[i]
        f = int(num )/ int(denom)
        L1.append(f)
    j = 0
    maxi=0
    while j <(len(L1)-1):
        if L1[j]<L1[j+1]:
             maxi=L1[j+1]   
        else:
            maxi=L1[j]           
        j=j+1
    ind= L1.index(maxi)
    return L[ind]

    
        

op="1"
while op !="0":
    menu()
    op= input("Introduza a opção:")
    if op=="1":
        numerador=int(input("Por favor, introduza o numerador que deseja: "))
        denominador=int(input("Por favor, introduza o denominador que deseja: "))
        F = verFrac(criarFrac( numerador, denominador))
        print(" A fração criada foi a seguinte: ", F)
 
        
        
    elif op == "2":
        numerador=int(input("Por favor, introduza o numerador que deseja: "))
        denominador=int(input("Por favor, introduza o denominador que deseja: "))
        F = verFrac(simplificarFrac(criarFrac(numerador, denominador)))
        print("A sua fração simplicada fica:", F)
        
        
    elif op=="3":
        numerador1=int(input("Por favor, introduza o numerador que deseja: "))
        denominador1=int(input("Por favor, introduza o denominador que deseja: "))
        frac1= criarFrac(numerador1, denominador1)
        
        numerador2=int(input("Por favor, introduza o numerador que deseja: "))
        denominador2=int(input("Por favor, introduza o denominador que deseja: "))
        frac2= criarFrac(numerador2, denominador2)
        
        SFrac= somarFrac( frac1, frac2)
        print("A soma das duas frações introduzidas é: ", SFrac)
        
    elif op=="4":
        numerador1=int(input("Por favor, introduza o numerador que deseja: "))
        denominador1=int(input("Por favor, introduza o denominador que deseja: "))
        frac1= criarFrac(numerador1, denominador1)
        
        numerador2=int(input("Por favor, introduza o numerador que deseja: "))
        denominador2=int(input("Por favor, introduza o denominador que deseja: "))
        frac2= criarFrac(numerador2, denominador2)
        
        DFrac= subtrairFrac( frac1, frac2)
        print("A subtração das duas frações introduzidas é: ", DFrac)
        
        
    elif op== "5":
        numerador1=int(input("Por favor, introduza o numerador que deseja: "))
        denominador1=int(input("Por favor, introduza o denominador que deseja: "))
        frac1= criarFrac(numerador1, denominador1)
        
        numerador2=int(input("Por favor, introduza o numerador que deseja: "))
        denominador2=int(input("Por favor, introduza o denominador que deseja: "))
        frac2= criarFrac(numerador2, denominador2)
        
        MFrac= multiplicarFrac(frac1, frac2)
        print("A multiplicação das duas frações introduzidas é: ", MFrac)
        
        
    elif op== "6":
        numerador1=int(input("Por favor, introduza o numerador que deseja: "))
        denominador1=int(input("Por favor, introduza o denominador que deseja: "))
        frac1= criarFrac(numerador1, denominador1)
        
        numerador2=int(input("Por favor, introduza o numerador que deseja: "))
        denominador2=int(input("Por favor, introduza o denominador que deseja: "))
        frac2= criarFrac(numerador2, denominador2)
        
        DFrac= dividirFrac(frac1, frac2)
        print("A divisão das duas frações introduzidas é: ", DFrac)
        
    
    elif op== "7":
        Lis= gerarLista()
        print(" A lista gerada automaticamente foi a seguinte: ", Lis)
        
    elif op=="8":
        Lista= gerarLista()
        print("A lista gerada automáticamente foi a seguinte: ", Lista)
        print(" O somatório dos elementos da sua lista deu:", somatorioLista( Lista) )
        
    elif op== "9":
        Lista1= gerarLista()
        Lista2= gerarLista()
        Lis= somarListas(Lista1, Lista2)
        print("A lista 1 gerada automáticamente foi a seguinte: ", Lista1)
        print("A lista 2 gerada automáticamente foi a seguinte: ", Lista2)
        print("A lista resultante da soma das duas listas geradas aleatóriamente deu: ", Lis)
            
    elif op== "10":
        Lista= gerarLista()
        Lis= maiorFrac(Lista)
        print("A lista gerada automáticamente foi a seguinte: ", Lista)
        print(" O maior elemento da sua lista é: ", Lis)
        
    elif op == "0":
         print("Até à próxima!")
    else:
         print("Opção inválida")
# Out:
#  Gestão para trabalhar com frações
#           Selecione a opção que pretende fazer:
#           (1)- Criar fração
#           (2)- Simplificar fração
#           (3)- Soma de frações
#           (4)- Subtração de frações
#           (5)- Multiplicação de frações
#           (6)- Divisão de frações
#           (7)- Gerar lista de n frações
#           (8)- Somatório dos elementos de uma lista
#           (9)- Somatório dos elementos de duas listas
#           (10)- Maior fração da lista
#           (0)- sair
#
# Introduza a opção:1
# Por favor, introduza o numerador que deseja: 1
# Por favor, introduza o denominador que deseja: 2
# 1/2
#  A fração criada foi a seguinte:  None
#  Gestão para trabalhar com frações
#           Selecione a opção que pretende fazer:
#           (1)- Criar fração
#           (2)- Simplificar fração
#           (3)- Soma de frações
#           (4)- Subtração de frações
#           (5)- Multiplicação de frações
#           (6)- Divisão de frações
# ...
