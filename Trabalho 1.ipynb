# %%
#alínea a)- jogador contra o computador

import random 
def fosforos():
     n=21
     j=input(" se pretender jogar em primeiro lugar prima 1. Se pretender jogar em segundo prima 2. ")
     if j== 1: 
       n1= (int(input("Retire 1, 2, 3 ou 4 fósforos:")))
        
       while n!=1:
             n1=(int(input("Retire 1, 2, 3 ou 4 fósforos:")))
             if n1>=5:
                 print ("Número Inválido")
             else:
                n=n-(n1)
                if n==1:
                    print ("n1 Ganhou!")
                    return n
                
                else: 
                    print ("Neste momento ainda estão em jogo", n, "fósforos.")
                    n2=random.randint(1,4)
                    if n2>= n:
                        print("Valor Impossível. Não tem esses fósforos disponíveis para retirar.")
                        while n2>= n:
                            n2= random.randint(1,4)
                    else:
                        print("n2 retirou", n2,"Fósforos.")
                        n=n-n2
                        print("De momento estão em jogo", n, "fósforos.")
                        if n>1: 
                            print("De momento ainda existem", n, "fósforos.")
                        elif n==1:
                            print("n2 ganhou!")
                        else: 
                            print("dddd")
     else:
        if j==2:
              while n!=1:
                  n1=random.randint(1,4)
                  if n1>=n:
                      while n1<n:
                          n1=random.randint(1,4)
                  else: 
                      print("n1 retirou:",n1,"fósforos")
                      n=n-n1
                    
                      if n==1: 
                        print("n1 ganhou!")
                      else:
                        print("De momento ainda estão em jogo", n, "fósforos.")
                        n2=(int(input("Retire 1, 2, 3 ou 4 fósforos:")))
                 
                        if n2>=5:
                            print ("Número inválido") 
                        else: 
                            n=n-n2
                            print("Neste momento estão em jogo", n, "fósforos.")
                        if n==1:
                            print("n2 ganhou!")
                            return n
                        else: 
                            print("Neste momento ainda estão em jogo", n, "fósforos.")
                         
fosforos()



#Alinea b)- computador a jigar em segundo lugar e a ganhar sempre.
    
def fosforos():
    n=21
    while n!=1:
        n1= (int(input ("Retire 1,2,3 ou 4 fósforos:")))
        if n1>=5:
            print ("Número inválido") 
        else: 
            n2= 5-n1
            print ("n2 retirou",n2, "fósforos:")
            n = n-(n1+n2)
            print ("De momento estão em jogo",n,"fósforos.")
            if n == 1:
                print("Apenas sobrou um fósforo! N2 ganhou!")
           
fosforos()  

#Alínea c)- computador a jogar em primeiro lugar e a tentar sempre apanhar um erro de raciocínio do jogador 

import random 
def fosforos():
    n=21
    n1=random.randit(1,4)
    n2=int(input("Retire 1, 2, 3 ou 4 fósforos:"))
    n=n-n1
    print ("De momento existem",n, "fósforos.") 
    op=True
    if n2>=5:
        print ("Número inválido")
        op= False
        while op==False:
            n=int(input("Retire 1,2,3 ou 4 fósforos:"))
            
            if n>=5: 
                print("Número inválido")
                op=False
            else:
                op=True
    else:
        n=n-n2
        print ("De momento existem",n,"fósforos")
        
        
    while (n1+n2) ==5:
        n1= random.randint(1,4)
        n=n-n1
        if n==1:
            print("De momento apenas sobra 1 fósforo!")
            return n
        else: 
            print("De momento existem",n,"fósforos.")
            n=int(input("Retire 1, 2 ,3 ou 4 fósforos:"))
            
            if n2>=5:
                print("Número inválido")
                op=False
                while op==False:
                    n2= int(input("Retire 1, 2, 3 ou 4 fósforos:"))
                    if n>=5:
                        print("Número inválido")
                        op=False
                    else:
                        op=True
            else:
                n=n-n2 
                if n==1:
                    print("De momento apenas está em jogo 1 fósforo. N2 ganhou!")
                    return n
                else:
                    print("De momento existem", n, "fósforos.") 
    if (n1+n2)<5:
        n1=5-(n1+n2)
        n=n-n1
        print("De momento existem", n,"fósforos.")
    elif (n1+n2)>5:
        n1=10-(n1+n2)
        print("De momento existem", n, "fósforos.")
    while n>1:
        n2= int(input("Retire 1 ,2, 3 ou 4 fósforos:")) 
        n=n-n2
        if n>=5:
            print("Número inválido") 
        else: 
            n1=5-n2
            n=n-n2
            print("De momento existem", n,"fósforos.")
            n=n-n1
            
            if n>1:
                print("De momento existem",n, "fósforos.")
            else:
                print("De momento apenas existe um fósforo! n1 ganhou!")
                return n 
        
fosforos()
