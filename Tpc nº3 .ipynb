# %% [markdown]
# ## Trabalho de casa nº3

# %% [markdown]
# **Identificador**: Trabalho
#
# **Título**: BubbleSort
#
# **Data início**: 2021-10-19 **Data fim**: 2021-10-23
#
# **Supervisor**: José Carlos Ramalho, https://www.di.uminho.pt/~jcr/thesup-v2.php
#
# **Autor**: Raquel Vitorino Lima

# %% [markdown]
# ### Resumo:

# %% [markdown]
# Com o trabalho proposto pretende-se desenvolver um código que organize crescentemente uma qualquer lista de números. Para tal, o que se faz são sucessivas trocas dos elementos adjacentes, até que estes fiquem ordenados corretamente. Para que o programa seja possível executar, tivemos de criar uma váriavel temporal para podermos fazer a sucessiva troca de 2 elementos. Quando o programa pára de fazer trocas significa que todas as trocas necessárias para a lista ficar ordenada foram realizadas e que por fim, temos a nossa lista ordenada.

# %% [markdown]
# ### Código:

# %%
from random import randint

def menu():
    print (""" Gestão listas de inteiros
           
           (1)- Introduza a lista "à mão"
           (2)- Gerar lista com valores aleatórios
           (3)- Maior elemento da lista 
           (4)- Bubble sort
           (0)- Sair
           """)
           
def criarListaM():
    lista=[]
    n=int(input("Introduza, por favor,o número de elementos da lista:"))
    for i in range(n):
        a= int(input("Introduza, por favor, o número " + str(i+1) + ":"))
        lista.append(a)
    return lista 


def criarListaA():
    n1=int(input("Introduza, por favor, o número de elementos da lista:"))
    lista=[]
    for i  in range (n1):
        element=randint(0,100)
        lista.append(element)
    return lista


def maiorElemento(lis):
    maximo=0
    i=0
    while i< len(lis):
        if lis[i] > maximo:
            maximo= lis[i]
        i=i+1
    return maximo


def bubbleSort(lis):
    trocas =1
    i=0
    
    while trocas !=0:
        for i in range (len(lis)):
            for j in range (len(lis)):
                if lis[j] > lis[i]:
                    v = lis[j]
                    lis[j] = lis[i]
                    lis[i]=v
                    print(lis)
                    trocas=trocas+1
    
            trocas=0   
    return lis

    lis2=bubbleSort(lis)

           


op="1"
while op !="0":
    menu()
    op= input("Introduza a opção:")
    if op=="1":
        lis = criarListaM()
        print(lis)
    elif op == "2":
        lis = criarListaA()
        print(lis)
        
        
        
        
    elif op=="3":
        op2=input(""""Pretende introduzir uma lista:
                   (1) à mão
                   (2) gerada aleatóriamente 
                   Resposta: """)
        if op2=="1":
            lis = criarListaM()
            print("Aqui está a lista onde vai ser procurado o maior elemento:", lis)
            lisElem=maiorElemento(lis)
            print("O maior elemento da sua lista é: ", lisElem)
        elif op2=="2":
            lis = criarListaA()
            print("Aqui está a lista onde vai ser procurado o maior elemento:", lis)
            lisElem=maiorElemento(lis)
            print("O maior elemento da sua lista é:", lisElem )
            
            
            
            
    elif op=="4":
        op2=input(""""Pretende introduzir uma lista:
                   (1) à mão
                   (2) gerada aleatóriamente 
                   Resposta: """)      
        if op2=="1":
            lis = criarListaM()
            print("Aqui está a sua lista que vai ser ordenada: ", lis)
            lisOrd= bubbleSort(lis)
            print("Aqui está a sua lista ordenada: ", lisOrd)
        elif op2=="2":
            lis = criarListaA()
            print("Aqui está a sua lista que vai ser ordenada: ", lis)
            lisOrd= bubbleSort(lis)
            print("Aqui está a sua lista ordenada: ", lisOrd)
# Out:
#  Gestão listas de inteiros
#
#            (1)- Introduza a lista "à mão"
#            (2)- Gerar lista com valores aleatórios
#            (3)- Maior elemento da lista
#            (4)- Bubble sort
#            (0)- Sair
#
# Introduza a opção:1
# Introduza, por favor,o número de elementos da lista:4
# Introduza, por favor, o número 1:12
# Introduza, por favor, o número 2:4
# Introduza, por favor, o número 3:20
# Introduza, por favor, o número 4:1
# [12, 4, 20, 1]
#  Gestão listas de inteiros
#
#            (1)- Introduza a lista "à mão"
#            (2)- Gerar lista com valores aleatórios
#            (3)- Maior elemento da lista
#            (4)- Bubble sort
#            (0)- Sair
#
# Introduza a opção:2
# Introduza, por favor, o número de elementos da lista:4
# [91, 73, 100, 90]
#  Gestão listas de inteiros
#
#            (1)- Introduza a lista "à mão"
#            (2)- Gerar lista com valores aleatórios
#            (3)- Maior elemento da lista
#            (4)- Bubble sort
# ...
